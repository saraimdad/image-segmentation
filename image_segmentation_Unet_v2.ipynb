# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate

from test_utils import summary, comparator

# %% [markdown]
# <a name='2'></a>
# ## 2 - Load and Split the Data

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import imageio

import matplotlib.pyplot as plt
# %matplotlib inline

path = ''
image_path = os.path.join(path, './data/CameraRGB/')
mask_path = os.path.join(path, './data/CameraMask/')
image_list = os.listdir(image_path)
mask_list = os.listdir(mask_path)
image_list = [image_path+i for i in image_list]
mask_list = [mask_path+i for i in mask_list]

# %% [markdown]
# ### Check out the some of the unmasked and masked images from the dataset:

# %%
N = 2
img = imageio.imread(image_list[N])
mask = imageio.imread(mask_list[N])
#mask = np.array([max(mask[i, j]) for i in range(mask.shape[0]) for j in range(mask.shape[1])]).reshape(img.shape[0], img.shape[1])

fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask[:, :, 0])
arr[1].set_title('Segmentation')
# Out:
# Text(0.5, 1.0, 'Segmentation')

# %% [markdown]
# <a name='2-1'></a>
# ### 2.1 - Split Dataset into Unmasked and Masked Images

# %%
image_list_ds = tf.data.Dataset.list_files(image_list, shuffle=False)
mask_list_ds = tf.data.Dataset.list_files(mask_list, shuffle=False)

for path in zip(image_list_ds.take(3), mask_list_ds.take(3)):
    print(path)
# Out:
# (<tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraRGB/000026.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraMask/000026.png'>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraRGB/000027.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraMask/000027.png'>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraRGB/000028.png'>, <tf.Tensor: shape=(), dtype=string, numpy=b'./data/CameraMask/000028.png'>)

# %%
image_filenames = tf.constant(image_list)
masks_filenames = tf.constant(mask_list)

dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))

for image, mask in dataset.take(1):
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'./data/CameraRGB/002128.png', shape=(), dtype=string)
# tf.Tensor(b'./data/CameraMask/002128.png', shape=(), dtype=string)

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Preprocessing Data

# %%
def process_path(image_path, mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.math.reduce_max(mask, axis=-1, keepdims=True)
    return img, mask

def preprocess(image, mask):
    input_image = tf.image.resize(image, (96, 128), method='nearest')
    input_mask = tf.image.resize(mask, (96, 128), method='nearest')

    return input_image, input_mask

image_ds = dataset.map(process_path)
processed_image_ds = image_ds.map(preprocess)

# %% [markdown]
# <a name='3'></a>
# ## 3 - U-Net

# %% [markdown]
# <a name='3-2'></a>
# ### 3.1 - Encoder (Downsampling Block)

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    """
    Convolutional downsampling block

    Arguments:
        inputs -- Input tensor
        n_filters -- Number of filters for the convolutional layers
        dropout_prob -- Dropout probability
        max_pooling -- Use MaxPooling2D to reduce the spatial dimensions of the output volume
    Returns:
        next_layer, skip_connection --  Next layer and skip connection outputs
    """

    conv = Conv2D(n_filters, # Number of filters
                  kernel_size=3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(inputs)
    conv = Conv2D(n_filters, # Number of filters
                  kernel_size=3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(conv)

    # if dropout_prob > 0
    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)


    # if max_pooling is True add a MaxPooling2D with 2x2 pool_size
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)

    else:
        next_layer = conv

    skip_connection = conv

    return next_layer, skip_connection

# %% [markdown]
# <a name='3-3'></a>
# ### 3.2 - Decoder (Upsampling Block)

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    """
    Convolutional upsampling block

    Arguments:
        expansive_input -- Input tensor from previous layer
        contractive_input -- Input tensor from previous skip layer
        n_filters -- Number of filters for the convolutional layers
    Returns:
        conv -- Tensor output
    """

    up = Conv2DTranspose(
                 n_filters,    # number of filters
                 kernel_size=3,    # Kernel size
                 strides=2,
                 padding='same')(expansive_input)

    # Merge the previous output and the contractive_input
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(n_filters, # Number of filters
                  kernel_size=3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(merge)
    conv = Conv2D(n_filters, # Number of filters
                  kernel_size=3,   # Kernel size
                  activation='relu',
                  padding='same',
                  kernel_initializer='he_normal')(conv)

    return conv

# %% [markdown]
# <a name='3-4'></a>
# ### 3.3 - Building the Model

# %%
def unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=23):
    """
    Unet model

    Arguments:
        input_size -- Input shape
        n_filters -- Number of filters for the convolutional layers
        n_classes -- Number of output classes
    Returns:
        model -- tf.keras.Model
    """
    inputs = Input(input_size)
    # Contracting Path (encoding)
    cblock1 = conv_block(inputs, n_filters)
    cblock2 = conv_block(cblock1[0], n_filters*2)
    cblock3 = conv_block(cblock2[0], n_filters*4)
    cblock4 = conv_block(cblock3[0], n_filters*8, dropout_prob=0.3)
    cblock5 = conv_block(cblock4[0], n_filters*16, dropout_prob=0.3, max_pooling=False)

    # Expanding Path (decoding)
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  n_filters*8)
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters*4)
    ublock8 = upsampling_block(ublock7, cblock2[1],  n_filters*2)
    ublock9 = upsampling_block(ublock8, cblock1[1],  n_filters)

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)

    conv10 = Conv2D(n_classes, kernel_size=1, padding='same')(conv9)

    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %% [markdown]
# <a name='3-5'></a>
# ### 3.4 - Set Model Dimensions

# %%
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))

# %% [markdown]
# ### Check out the model summary below!

# %%
unet.summary()
# Out:
# Model: "functional_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 96, 128, 3)] 0
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 96, 128, 32)  896         input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 96, 128, 32)  9248        conv2d_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 48, 64, 32)   0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 48, 64, 64)   18496       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 48, 64, 64)   36928       conv2d_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 24, 32, 64)   0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 24, 32, 128)  73856       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 24, 32, 128)  147584      conv2d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 12, 16, 128)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 16, 256)  295168      max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 16, 256)  590080      conv2d_60[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 16, 256)  0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 6, 8, 256)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 6, 8, 512)    1180160     max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 6, 8, 512)    2359808     conv2d_62[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 6, 8, 512)    0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 12, 16, 256)  1179904     dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 12, 16, 512)  0           conv2d_transpose_9[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 12, 16, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 12, 16, 256)  590080      conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 24, 32, 128)  295040      conv2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 24, 32, 256)  0           conv2d_transpose_10[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 24, 32, 128)  295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 24, 32, 128)  147584      conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 48, 64, 64)   73792       conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 48, 64, 128)  0           conv2d_transpose_11[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 48, 64, 64)   73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 48, 64, 64)   36928       conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 96, 128, 32)  18464       conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 96, 128, 64)  0           conv2d_transpose_12[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 96, 128, 32)  18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 96, 128, 32)  9248        conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 96, 128, 32)  9248        conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 96, 128, 23)  759         conv2d_72[0][0]
# ==================================================================================================
# Total params: 8,640,471
# Trainable params: 8,640,471
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <a name='3-6'></a>
# ### 3.5 - Loss Function

# %%
unet.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# <a name='3-7'></a>
# ### 3.6 - Dataset Handling

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
for image, mask in image_ds.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display([sample_image, sample_mask])
# Out:
# (480, 640, 1)

# %%
for image, mask in processed_image_ds.take(1):
    sample_image, sample_mask = image, mask
    print(mask.shape)
display([sample_image, sample_mask])
# Out:
# (96, 128, 1)

# %% [markdown]
# <a name='4'></a>
# ## 4 - Train the Model

# %%
EPOCHS = 40
VAL_SUBSPLITS = 5
BUFFER_SIZE = 500
BATCH_SIZE = 32
processed_image_ds.batch(BATCH_SIZE)
train_dataset = processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(processed_image_ds.element_spec)
model_history = unet.fit(train_dataset, epochs=EPOCHS)
# Out:
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# Epoch 1/40
# 34/34 [==============================] - 20s 575ms/step - loss: 1.8799 - accuracy: 0.4835
# Epoch 2/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.8460 - accuracy: 0.7905
# Epoch 3/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.5788 - accuracy: 0.8347
# Epoch 4/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.4951 - accuracy: 0.8564
# Epoch 5/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3981 - accuracy: 0.8811
# Epoch 6/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.3475 - accuracy: 0.8958
# Epoch 7/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3081 - accuracy: 0.9076
# Epoch 8/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2681 - accuracy: 0.9205
# Epoch 9/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2351 - accuracy: 0.9300
# Epoch 10/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2211 - accuracy: 0.9341
# Epoch 11/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1983 - accuracy: 0.9408
# Epoch 12/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1828 - accuracy: 0.9453
# Epoch 13/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1686 - accuracy: 0.9495
# Epoch 14/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.1649 - accuracy: 0.9503
# Epoch 15/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1539 - accuracy: 0.9540
# Epoch 16/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1409 - accuracy: 0.9577
# Epoch 17/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1349 - accuracy: 0.9598
# Epoch 18/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1273 - accuracy: 0.9621
# Epoch 19/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1194 - accuracy: 0.9645
# Epoch 20/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1135 - accuracy: 0.9661
# Epoch 21/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1128 - accuracy: 0.9661
# Epoch 22/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1127 - accuracy: 0.9661
# Epoch 23/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.1033 - accuracy: 0.9689
# Epoch 24/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.1000 - accuracy: 0.9699
# Epoch 25/40
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0976 - accuracy: 0.9703
# Epoch 26/40
# 34/34 [==============================] - 1s 41ms/step - loss: 1.4038 - accuracy: 0.6561
# Epoch 27/40
# 34/34 [==============================] - 1s 41ms/step - loss: 1.8643 - accuracy: 0.5835
# Epoch 28/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.9340 - accuracy: 0.7529
# Epoch 29/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.5651 - accuracy: 0.8470
# Epoch 30/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.4852 - accuracy: 0.8624
# Epoch 31/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.4348 - accuracy: 0.8731
# Epoch 32/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3995 - accuracy: 0.8810
# Epoch 33/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3770 - accuracy: 0.8858
# Epoch 34/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3508 - accuracy: 0.8917
# Epoch 35/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3294 - accuracy: 0.8985
# Epoch 36/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3224 - accuracy: 0.9013
# Epoch 37/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.3094 - accuracy: 0.9059
# Epoch 38/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2915 - accuracy: 0.9119
# Epoch 39/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2855 - accuracy: 0.9139
# Epoch 40/40
# 34/34 [==============================] - 1s 40ms/step - loss: 0.2745 - accuracy: 0.9173

# %% [markdown]
# <a name='4-1'></a>
# ### 4.1 - Create Predicted Masks

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Model Accuracy

# %%
plt.plot(model_history.history["accuracy"])

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Predictions

# %%
def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet.predict(sample_image[tf.newaxis, ...]))])

# %%
show_predictions(train_dataset, 6)
